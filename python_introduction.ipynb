# %%
print("Everything is working fine!")
# Out:
# Everything is working fine!

# %%
# Get the current working directory

import os
os.getcwd()
# Out:
# 'e:\\workshop_ML\\python_tutorials'

# %%
# Addition

print(3+4)
# Out:
# 7

# %%
# Subtraction

print(3-4)
# Out:
# -1

# %%
# Multiplication

print(3*4)
# Out:
# 12

# %%
# Division

print(3/4)
# Out:
# 0.75

# %%
# Exponentiation

print(3**4)
# Out:
# 81

# %%
# Modulus

print(4%3)
# Out:
# 1

# %%
# Floor Division

print(13//4)
# Out:
# 3

# %%
# Checking data types

print(type(4))                  # Int
# Out:
# <class 'int'>

# %%
# Checking data types

print(type(4.5))                  # Float
# Out:
# <class 'float'>

# %%
# Checking data types

print(type(4 + 3j))                  # Complex
# Out:
# <class 'complex'>

# %%
# Checking data types

print(type("Anant"))                 # Int
# Out:
# <class 'str'>
